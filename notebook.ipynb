# %%
# show result of last expression even if it was an assignment
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %% [markdown]
# # Step 1: The Station List

# %%
import json
from pathlib import Path

# JSON data from 
# https://layer.bicyclesharing.net/map/v1/fgb/map-inventory
map_json_path = Path("./map.json")
with map_json_path.open() as f:
    map_json = json.load(f)

# %%
from typing import NamedTuple

class Station(NamedTuple):
    lat: float
    lon: float
    name: str
    id: str
       
    @property
    def lonlat(self):
        return self.lon, self.lat
       
    @property
    def latlon(self):
        return self.lat, self.lon
        
    def __repr__(self):
        return f"{self.lat:9.4f} {self.lon:9.4f} {self.id:10} {self.name[:30]}"

# %%
stations = [
    Station(
        lat=feature["geometry"]["coordinates"][1],
        lon=feature["geometry"]["coordinates"][0],
        name=feature["properties"]["station"]["name"],
        id=feature["properties"]["station"]["terminal"],
    ) 
    for feature in map_json["features"] 
    if feature["properties"].get("station", {}).get("installed")
]
# Out:
# [  37.7864 -122.4049 SF-G27     Powell St BART Station (Market,
#    37.7859 -122.4089 SF-G26     Cyril Magnin St at Ellis St,
#    37.7839 -122.4084 SF-H26     Powell St BART Station (Market,
#    37.8048 -122.4032 SF-A27     The Embarcadero at Sansome St,
#    37.8046 -122.2717 OK-L5      Frank H Ogawa Plaza,
#    37.8000 -122.3985 SF-C28-1   The Embarcadero at Vallejo St,
#    37.7986 -122.4009 SF-C28-2   Broadway at Battery St,
#    37.7954 -122.4048 SF-D27     Washington St at Kearny St,
#    37.7973 -122.3984 SF-D28     Davis St at Jackson St,
#    37.7942 -122.4029 SF-E27     Commercial St at Montgomery St,
#    37.7950 -122.4000 SF-E28     Clay St at Battery St,
#    37.7954 -122.3942 SF-E29-1   San Francisco Ferry Building (,
#    37.7941 -122.3944 SF-E29-2   Steuart St at Market St,
#    37.7923 -122.3971 SF-E29-3   Embarcadero BART Station (Beal,
#    37.8502 -122.2602 OK-A2      Telegraph Ave at Alcatraz Ave,
#    37.7890 -122.4035 SF-F27     Post St at Kearny St,
#    37.7913 -122.3991 SF-F28-1   Mechanics Monument Plaza (Mark,
#    37.7896 -122.4008 SF-F28-2   Montgomery St BART Station (Ma,
#    37.7898 -122.3946 SF-F29     Howard St at Beale St,
#    37.7915 -122.3910 SF-F30-1   The Embarcadero at Steuart St,
#    37.7897 -122.3904 SF-F30-2   Spear St at Folsom St,
#    37.7875 -122.3974 SF-G28-1   Howard St at 2nd St,
#    37.7873 -122.3944 SF-G29-2   1st St at Folsom St,
#    37.7881 -122.3919 SF-G30-1   Beale St at Harrison St,
#    37.7872 -122.3881 SF-G30-2   The Embarcadero at Bryant St,
#    37.7824 -122.4394 SF-H18     O'Farrell St at Divisadero St,
#    37.7766 -122.3953 SF-J29     San Francisco Caltrain (Townse,
#    37.7838 -122.4346 SF-H19     Raymond Kimbell Playground,
#    37.7816 -122.4154 SF-H24     Golden Gate Ave at Hyde St,
#    37.7840 -122.4124 SF-H25     Father Alfred E Boeddeker Park,
#    37.3291 -121.9046 SJ-M6      Cahill Park,
#    37.7838 -122.3989 SF-H28     Folsom St at 3rd St,
#    37.7850 -122.3959 SF-H29     2nd St at Folsom St,
#    37.7790 -122.4369 SF-I19     Scott St at Golden Gate Ave,
#    37.7813 -122.4187 SF-I23-1   Golden Gate Ave at Polk St,
#    37.7786 -122.4182 SF-I23-2   San Francisco City Hall (Polk ,
#    37.7788 -122.4159 SF-I24     San Francisco Public Library (,
#    37.7811 -122.4117 SF-I25     Civic Center/UN Plaza BART Sta,
#    37.7901 -122.2424 OK-L12     San Antonio Park,
#    37.7810 -122.3997 SF-I28     4th St at Harrison St,
#    37.7808 -122.3950 SF-I29-2   S Park St at 3rd St,
#    37.7805 -122.3903 SF-I30     2nd St at Townsend St,
#    37.7774 -122.4418 SF-J17     McAllister St at Baker St,
#    37.7759 -122.4378 SF-J18     Grove St at Divisadero,
#    37.7771 -122.4296 SF-J20     Webster St at Grove St,
#    37.7734 -122.4273 SF-K21     Koshland Park,
#    37.7766 -122.4174 SF-J23-1   Market St at 10th St,
#    37.7748 -122.4190 SF-J23-2   S Van Ness Ave at Market St,
#    37.7745 -122.4094 SF-J24     8th St at Ringold St,
#    37.7765 -122.4113 SF-J25     Howard St at 8th St,
#    37.7778 -122.4064 SF-J26     Victoria Manalo Draves Park,
#    37.7759 -122.4026 SF-J27     Bryant St at 6th St,
#    37.7768 -122.3990 SF-J28     5th St at Brannan St,
#    37.7787 -122.3927 SF-J29-1   3rd St at Townsend St,
#    37.7766 -122.3955 SF J29-3   San Francisco Caltrain Station,
#    37.7733 -122.4443 SF-K17     Central Ave at Fell St,
#    37.7731 -122.4391 SF-K18     Broderick St at Oak St,
#    37.7724 -122.4356 SF-K19     Page St at Scott St,
#    37.7718 -122.4337 SF-K20     Pierce St at Haight St,
#    37.7764 -122.4262 SF-J21     Laguna St at Hayes St,
#    37.7738 -122.4212 SF-K22-1   Market St at Franklin St,
#    37.7717 -122.4224 SF-K22-2   McCoppin St at Valencia St,
#    37.7735 -122.4160 SF-K24     11th St at Natoma St,
#    37.7737 -122.4116 SF-K25     Folsom St at 9th St,
#    37.7735 -122.4037 SF-K27     7th St at Brannan St,
#    37.7753 -122.3974 SF-K28     Townsend St at 5th St,
#    37.7759 -122.3932 SF-K29-1   Berry St at 4th St,
#    37.7692 -122.4338 SF-L19     Duboce Park,
#    37.7701 -122.4292 SF-L20     Church St at Duboce Ave,
#    37.7693 -122.4268 SF-L21     Market St at Dolores St,
#    37.7698 -122.4157 SF-L24     Folsom St at 13th St,
#    37.7700 -122.4117 SF-L25     11th St at Bryant St,
#    37.7692 -122.4076 SF-L26     Division St at Potrero Ave,
#    37.7711 -122.4027 SF-L27     Townsend St at 7th St,
#    37.7718 -122.3984 SF-L28     Berry St at King St,
#    37.7723 -122.3930 SF-L29     Mission Bay Kids Park,
#    37.7704 -122.3912 SF-L30-1   4th St at Mission Bay Blvd S,
#    37.7662 -122.4311 SF-M20     Sanchez St at 15th St,
#    37.7662 -122.4266 SF-M21     Dolores St at 15th St,
#    37.7683 -122.4201 SF-M22-1   14th St at Mission St,
#    37.7651 -122.4219 SF-M22-2   Valencia St at 16th St,
#    37.7670 -122.4154 SF-M24     Folsom St at 15th St,
#    37.7671 -122.4107 SF-M25     Bryant St at 15th St,
#    37.7660 -122.4057 SF-M26     San Bruno Ave at 16th St,
#    37.7669 -122.3996 SF-M27     Irwin St at 8th St,
#    37.7670 -122.3908 SF-M30     4th St at 16th St,
#    37.7643 -122.4318 SF-N20-1   16th St at Prosper St,
#    37.7632 -122.4307 SF-N20-2   Sanchez St at 17th St,
#    37.7630 -122.4265 SF-N21     17th St at Dolores St,
#    37.7647 -122.4200 SF-N22-1A  16th St Mission BART,
#    37.7633 -122.4219 SF-N22-2   17th St at Valencia St,
#    37.7637 -122.4152 SF-N23     17th & Folsom Street Park (17t,
#    37.7638 -122.4130 SF-N24-2   Harrison St at 17th St,
#    37.7646 -122.4103 SF-N25     Franklin Square,
#    37.7645 -122.4026 SF-N27     Rhode Island St at 17th St,
#    37.7650 -122.3988 SF-N28     Jackson Playground,
#    37.7648 -122.3948 SF-N29     Mississippi St at 17th St,
#    37.7592 -122.4369 SF-O18     Eureka Valley Recreation Cente,
#    37.7610 -122.4326 SF-O19     18th St at Noe St,
#    37.7614 -122.4264 SF-O21     Mission Dolores Park,
#    37.7592 -122.4213 SF-O22     Mission Playground,
#    37.7603 -122.4189 SF-O23     19th St at Mission St,
#    37.7606 -122.4148 SF-O24     Folsom St at 19th St,
#    37.7604 -122.4108 SF-O25-1   19th St at Florida St,
#    37.7592 -122.4099 SF-O25-2   20th St at Bryant St,
#    37.7616 -122.3906 SF-O30     Esprit Park,
#    37.7567 -122.4210 SF-P22     Valencia St at 21st St,
#    37.7589 -122.4125 SF-P24     Harrison St at 20th St,
#    37.7574 -122.3921 SF-P30     22nd St Caltrain Station,
#    37.7518 -122.4266 SF-Q21-2   24th St at Chattanooga St,
#    37.7552 -122.4210 SF-Q22-1   Valencia St at 22nd St,
#    37.7524 -122.4206 SF-Q22-2   Valencia St at 24th St,
#    37.7505 -122.4339 SF-R19     Jersey St at Castro St,
#    37.7509 -122.4274 SF-R20     Jersey St at Church St,
#    37.7510 -122.4119 SF-R24     Garfield Square (25th St at Ha,
#    37.7479 -122.4250 SF-S21     Cesar Chavez St at Dolores St,
#    37.7480 -122.4202 SF-S22-1   Valencia St at Cesar Chavez St,
#    37.7473 -122.4114 SF-S24     Precita Park,
#    37.7437 -122.4268 SF-T20     29th St at Church St,
#    37.7423 -122.4232 SF-T21     30th St at San Jose Ave,
#    37.7441 -122.4215 SF-T22     29th St at Tiffany Ave,
#    37.8297 -122.2876 EM-D2      Horton St at 40th St,
#    37.8313 -122.2856 EM-D3      Emeryville Town Hall,
#    37.8313 -122.2783 EM-D4      Adeline St at 40th St,
#    37.8362 -122.2872 EM-C2      53rd St at Hollis St,
#    37.8356 -122.2811 EM-C3      47th St at San Pablo Ave,
#    37.8409 -122.2914 EM-A1      59th St at Horton St,
#    37.8419 -122.2880 EM-A2      Doyle St at 59th St,
#    37.8405 -122.2935 EM-B1      Emeryville Public Market,
#    37.8384 -122.2887 EM-B2      Stanford Ave at Hollis St,
#    37.8468 -122.2914 EM-C1      65th St at Hollis St,
#    37.8333 -122.2635 OK-E4      Shattuck Ave at Telegraph Ave,
#    37.8161 -122.2782 OK-J3      24th St at Market St,
#    37.8053 -122.2948 OK-M1      West Oakland BART Station,
#    37.8005 -122.2721 OK-M6      Franklin St at 9th St,
#    37.7973 -122.2653 OK-M7      Lake Merritt BART Station,
#    37.8150 -122.2748 OK-J4      Isabella St at San Pablo Ave,
#    37.8514 -122.2525 BK-A3      College Ave at Alcatraz Ave,
#    37.8482 -122.2522 OK-A4      College Ave at Harwood Ave,
#    37.8496 -122.2656 OK-B1      Alcatraz Ave at Shattuck Ave,
#    37.8465 -122.2653 OK-B2      Bushrod Park,
#    37.8445 -122.2614 OK-B3      Telegraph Ave at 58th St,
#    37.8443 -122.2519 OK-B4      Rockridge BART Station,
#    37.8418 -122.2515 OK-B5      College Ave at Taft Ave,
#    37.8404 -122.2645 OK-D3-1    Shattuck Ave at 55th St,
#    37.8368 -122.2640 OK-D3-2    Shattuck Ave at 51st St,
#    37.8359 -122.2624 OK-D4      49th St at Telegraph Ave,
#    37.8284 -122.2663 OK-F4      MacArthur BART Station,
#    37.8263 -122.2651 OK-G4      MacArthur Blvd at Telegraph Av,
#    37.8194 -122.2619 OK-H5      Broadway at 30th St,
#    37.8161 -122.2679 OK-I5      Telegraph Ave at 27th St,
#    37.8127 -122.2688 OK-J5      Telegraph Ave at 23rd St,
#    37.8114 -122.2652 OK-J6-1    Grand Ave at Webster St,
#    37.8090 -122.2682 OK-K5-2    19th Street BART Station,
#    37.8087 -122.2699 OK-K5-1    Telegraph Ave at 19th St,
#    37.8013 -122.2626 OK-L7-2    Lakeside Dr at 14th St,
#    37.7962 -122.2794 OK-N6      Jack London Square,
#    37.8426 -122.2677 OK-C2      Dover St at 57th St,
#    37.8396 -122.2718 OK-D2      Genoa St at 55th St,
#    37.8302 -122.2710 OK-F3      West St at 40th St,
#    37.8305 -122.2739 OK-G2      Market St at 40th St,
#    37.8267 -122.2718 OK-G3      37th St at West St,
#    37.8127 -122.2472 OK-H9-1    Grand Ave at Santa Clara Ave,
#    37.8111 -122.2433 OK-H9-2    Lakeshore Ave at Trestle Glen ,
#    37.8123 -122.2608 OK-I6      Bay Pl at Vernon St,
#    37.8089 -122.2565 OK-I8      Grand Ave at Perkins St,
#    37.8088 -122.2497 OK-I9      El Embarcadero at Grand Ave,
#    37.8078 -122.2645 OK-J6-2    Snow Park,
#    37.8002 -122.2538 OK-K9      2nd Ave at E 18th St,
#    37.7977 -122.2630 OK-L8      10th St at Fallon St,
#    37.8008 -122.2749 OK-M5      Washington St at 8th St,
#    37.7952 -122.2740 OK-N7      Webster St at 2nd St,
#    37.8402 -122.2618 OK-C3      55th St at Telegraph Ave,
#    37.8379 -122.2572 OK-C4      Shafter Ave at Cavour St,
#    37.8381 -122.2513 OK-C5      College Ave at Bryant Ave,
#    37.8358 -122.2516 OK-D5      Broadway at Coronado Ave,
#    37.3328 -121.8839 SJ-N10-1   S. 4th St at San Carlos St,
#    37.8336 -122.2674 OK-E3      45th St at MLK Jr Way,
#    37.8333 -122.2562 OK-E5      45th St at Manila,
#    37.8278 -122.2567 OK-F5      Broadway at 40th St,
#    37.8249 -122.2605 OK-G5      Mosswood Park,
#    37.8238 -122.2812 OK-H2      32nd St at Adeline St,
#    37.8233 -122.2757 OK-H3      Market St at Brockhurst St,
#    37.8225 -122.2663 OK-H4-3    34th St at Telegraph Ave,
#    37.8178 -122.2757 OK-I3      San Pablo Ave at 27th St,
#    37.8170 -122.2718 OK-I4      27th St at MLK Jr Way,
#    37.8123 -122.2852 OK-K2      DeFremery Park,
#    37.8098 -122.2802 OK-K3      Marston Campbell Park,
#    37.8114 -122.2734 OK-K4      San Pablo Ave at MLK Jr Way,
#    37.7944 -122.2539 OK-L10     12th St at 6th Ave,
#    37.7927 -122.2488 OK-L11     10th Ave at E 15th St,
#    37.7648 -122.4201 SF-N22-1B  16th St Mission BART Station 2,
#    37.7852 -122.2389 OK-L13     21st Ave at International Blvd,
#    37.7852 -122.2344 OK-L14     23rd Ave at Foothill Blvd,
#    37.7811 -122.2330 OK-L15     26th Ave at International Blvd,
#    37.7838 -122.2226 OK-L16     Foothill Blvd at Fruitvale Ave,
#    37.7799 -122.2177 OK-L17     Foothill Blvd at Harrington Av,
#    37.7757 -122.2130 OK-L18     Foothill Blvd at 42nd Ave,
#    37.8107 -122.2914 OK-L2      14th St at Mandela Pkwy,
#    37.8087 -122.2833 OK-L3      14th St at Filbert St,
#    37.8062 -122.2760 OK-L4      MLK Jr Way at 14th St,
#    37.7958 -122.2556 OK-L9      12th St at 4th Ave,
#    37.7777 -122.2258 OK-M16     Fruitvale Ave at International,
#    37.8072 -122.2894 OK-M2      Union St at 10th St,
#    37.8037 -122.2825 OK-M3      Market St at 8th St,
#    37.7752 -122.2245 OK-N17     Fruitvale BART Station,
#    37.8717 -122.2731 BK-C6      MLK Jr Way at University Ave,
#    37.8688 -122.2588 BK-E9-1    Bancroft Way at Telegraph Ave,
#    37.8660 -122.2588 BK-E9-2    Haste St at Telegraph Ave,
#    37.8525 -122.2702 BK-H6      Ashby BART Station,
#    37.8601 -122.2694 BK-F7      Milvia St at Derby St,
#    37.8694 -122.2543 BK-E10     Bancroft Way at College Ave,
#    37.8738 -122.2686 BK-C7      Shattuck Ave at Hearst Ave,
#    37.8703 -122.2678 BK-D7-1    Downtown Berkeley BART,
#    37.8691 -122.2706 BK-D7-2    Berkeley Civic Center,
#    37.8678 -122.2659 BK-E8      Fulton St at Bancroft Way,
#    37.8560 -122.2598 BK-H9      Telegraph Ave at Ashby Ave,
#    37.8585 -122.2533 BK-H10     Russell St at College Ave,
#    37.8740 -122.2830 BK-C5      North Berkeley BART Station,
#    37.8706 -122.2797 BK-D5      California St at University Av,
#    37.8658 -122.2674 BK-E7      Channing Way at Shattuck Ave,
#    37.8664 -122.2538 BK-E10-    Haste St at College Ave,
#    37.8802 -122.2696 BK-A7      Vine St at Shattuck Ave,
#    37.8766 -122.2695 BK-B7      Virginia St at Shattuck Ave,
#    37.8751 -122.2606 BK-B9      Hearst Ave at Euclid Ave,
#    37.8704 -122.2997 BK-C1      Fifth St at Delaware St,
#    37.8724 -122.2664 BK-C8      University Ave at Oxford St,
#    37.8662 -122.2994 BK-D1      Addison St at Fourth St,
#    37.8628 -122.2902 BK-E2      Channing Way at San Pablo Ave,
#    37.8589 -122.2912 BK-F2      Ninth St at Parker St,
#    37.8625 -122.2648 BK-F8      Parker St at Fulton St,
#    37.8618 -122.2536 BK-F10     Derby St at College Ave,
#    37.8575 -122.2616 BK-G8      Ellsworth St at Russell St,
#    37.8623 -122.2588 BK-G9      Telegraph Ave at Carleton St,
#    37.8535 -122.2894 BK-H3      Ninth St at Heinz Ave,
#    37.8558 -122.2831 BK-G4      San Pablo Park,
#    37.8506 -122.2782 BK-H5      Woolsey St at Sacramento St,
#    37.8556 -122.2636 BK-H8      Fulton St at Ashby Ave,
#    37.8576 -122.2676 BK-G7      Oregon St at Adeline St,
#    37.3430 -121.8889 SJ-K11     Julian St at 6th St,
#    37.3322 -121.9125 SJ-K5      Julian St at The Alameda,
#    37.3337 -121.9086 SJ-K6      Morrison Ave at Julian St,
#    37.3319 -121.9049 SJ-L7-2    The Alameda at Bush St,
#    37.3391 -121.8841 SJ-M11-1   Santa Clara St at 7th St,
#    37.3372 -121.8831 SJ-M11-2   San Fernando at 7th St,
#    37.3384 -121.8808 SJ-M11-3   9th St at San Fernando,
#    37.3324 -121.8903 SJ-M9-1    Market St at Park St,
#    37.3303 -121.8977 SJ-M8-2    Delmas Ave and San Fernando St,
#    37.7849 -122.4009 SF-H27-1   Yerba Buena Center for the Art,
#    37.7835 -122.4312 SF-H20     Webster St at O'Farrell St,
#    37.3365 -121.8766 SJ-N12-1   San Carlos St at 11th St,
#    37.3267 -121.8893 SJ-O9      Almaden Blvd at Balbach St,
#    37.3510 -121.9020 SJ-H10     Mission St at 1st St,
#    37.3510 -121.8959 SJ-I10     5th St at Taylor St,
#    37.3477 -121.8995 SJ-I9      George St at 1st St,
#    37.3413 -121.9032 SJ-J8      Autumn Parkway at Coleman Ave,
#    37.3449 -121.8970 SJ-J9      Empire St at 1st St,
#    37.3276 -121.8846 SJ-O10     Pierce Ave at Market St,
#    37.3328 -121.8759 SJ-O11     William St at 10th St,
#    37.3260 -121.8771 SJ-P10     5th St at Virginia St,
#    37.3230 -121.8879 SJ-P8      Locust St at Grant St,
#    37.3221 -121.8811 SJ-P9      Oak St at 1st St,
#    37.3237 -121.8741 SJ-Q10     Bestor Art Park,
#    37.3173 -121.8850 SJ-Q8      Palm St at Willow St,
#    37.3184 -121.8832 SJ-Q9      Willow St at Vine St,
#    37.3129 -121.8829 SJ-R8      Tamien Station,
#    37.3526 -121.9057 SJ-H9      San Pedro St at Hedding St,
#    37.3488 -121.8948 SJ-J10     Jackson St at 5th St,
#    37.3427 -121.8956 SJ-K9      Ryland Park,
#    37.3393 -121.8899 SJ-L10     Saint James Park,
#    37.3327 -121.9001 SJ-L7-1    SAP Center,
#    37.3368 -121.8941 SJ-L9      San Pedro Square,
#    37.3374 -121.8870 SJ-M10-1   San Jose City Hall,
#    37.3359 -121.8857 SJ-M10-2   San Fernando St at 4th St,
#    37.3338 -121.8869 SJ-M10-3   Paseo De San Antonio at 2nd St,
#    37.3297 -121.9018 SJ-M7-1    San Jose Diridon Station,
#    37.3314 -121.8932 SJ-M8      Almaden Blvd at San Fernando S,
#    37.3340 -121.8949 SJ-M9-2    Santa Clara St at Almaden Blvd,
#    37.8342 -122.2730 OK-E2      Market St at 45th St,
#    37.3302 -121.8858 SJ-N10-2   San Salvador St at 1st St,
#    37.3340 -121.8773 SJ-N11     San Salvador St at 9th St,
#    37.3307 -121.8890 SJ-N9      San Carlos St at Market St,
#    37.7801 -122.4031 SF-I27     5th at Folsom,
#    37.7980 -122.4060 SF-C26     Broadway at Kearny,
#    37.7883 -122.4085 SF-F26     Union Square (Powell St at Pos,
#    37.3320 -121.8818 SJ-N10-3   5th St at San Salvador St,
#    37.7633 -122.4074 SF-N26     Potrero Ave and Mariposa St,
#    37.8070 -122.2666 OK-K6-     Webster St at 19th St,
#    37.8032 -122.2706 OK-L6-     13th St at Franklin St,
#    37.8000 -122.2664 OK-L7      Jackson St at 11th St,
#    37.8497 -122.2706 BK-I6      Harmon St at Adeline St,
#    37.3362 -121.8893 SJ-M10-4   Fountain Alley at S 2nd St,
#    37.7832 -122.3936 SF I29-1   Bryant St at 2nd St,
#    37.7665 -122.3983 SF-M28     Hubbell St at 16th St,
#    37.7810 -122.4057 SF-I26-    Howard St at Mary St,
#    37.7714 -122.4058 SF-K26     8th St at Brannan St,
#    37.7554 -122.3888 SF-Q30     23rd St at Tennessee St,
#    37.7692 -122.4223 SF-L22     Valencia St at Clinton Park]

# %%
from collections import Counter
prefixes = Counter([st.id.split("-")[0] for st in stations])
prefixes.most_common()
# Out:
# [('SF', 128),
#  ('OK', 79),
#  ('SJ', 44),
#  ('BK', 35),
#  ('EM', 10),
#  ('SF J29', 1),
#  ('SF I29', 1)]

# %%
stations = [st for st in stations if st.id[:2] in {"OK", "BK", "EM"}]
len(stations)
# Out:
# 124

# %% [markdown]
# # Step 2: Folium for Mapping

# %%
import folium

def basemap(stations):
    center_lat = 0.5 * (min(st.lat for st in stations) + max(st.lat for st in stations))
    center_lon = 0.5 * (min(st.lon for st in stations) + max(st.lon for st in stations))
    
    mymap = folium.Map(
        location=[center_lat, center_lon], 
        zoom_start=12,
        tiles='Stamen Terrain',
    )

    for st in stations:
        folium.Circle(
            location=st.latlon, 
            radius=50,
            popup=f"<strong>{st.id}</strong> {st.name}",
            color='red',
            fill=True,
            fill_color='red',
            fill_opacity=1.0,
        ).add_to(mymap)
        
    return mymap

# %%
basemap(stations)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Step 3: Traveling Salesman with OR Tools

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

manager = pywrapcp.RoutingIndexManager(
    len(stations),  # number of stations
    1,              # number of vehicles
    0,              # index of start/finish station
)
routing = pywrapcp.RoutingModel(manager)
# Out:
# <ortools.constraint_solver.pywrapcp.RoutingModel; proxy of <Swig Object of type 'operations_research::RoutingModel *' at 0x10d098510> >

# %%
from geopy.distance import distance

def as_the_bird_flies(from_station: Station, to_station: Station):
    """Returns distance between two stations in whole meters"""
    dist = distance(from_station.latlon, to_station.latlon)
    return int(dist.meters)  

def cost_function(from_index, to_index):
    """Cost function for OR Tools"""
    from_station = stations[manager.IndexToNode(from_index)]
    to_station = stations[manager.IndexToNode(to_index)]
    return as_the_bird_flies(from_station, to_station)

# %%
# not a particularly Pythonic API...
callback_ptr = routing.RegisterTransitCallback(cost_function)
routing.SetArcCostEvaluatorOfAllVehicles(callback_ptr)
search_parameters = pywrapcp.DefaultRoutingSearchParameters()
search_parameters.time_limit.seconds = 120

# This lines will run for a few minutes!
assignment = routing.SolveWithParameters(search_parameters)

total_dist = assignment.ObjectiveValue()
print(f"Distance: {total_dist/1000:.3} km ({total_dist/1609:.3} mi)")
# Out:
# Distance: 64.7 km (40.2 mi)

# %%
def route_from_ortools_solution(assignment, routing, manager):
    index = routing.Start(0)
    route = []
    while not routing.IsEnd(index):
        previous_index = index
        index = assignment.Value(routing.NextVar(index))
        route.append((
            stations[manager.IndexToNode(previous_index)],
            stations[manager.IndexToNode(index)]
        ))
    return route

route = route_from_ortools_solution(assignment, routing, manager)
routemap = basemap(stations)

for st1, st2 in route:
    folium.PolyLine([st1.latlon, st2.latlon]).add_to(routemap)

routemap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Step 4: Real cycling directions from Mapbox

# %%
import mapbox

service = mapbox.Directions(access_token="secret")

# %%
class Route(NamedTuple):
    distance: float
    duration: float
    polyline: folium.PolyLine


def get_route_from_mapbox(from_station, to_station):
    """Fetch directions from Mapbox API and turn into Folium polyline"""
    resp = service.directions(
        [from_station.lonlat, to_station.lonlat],
        profile="mapbox/cycling",
        geometries="polyline",
    ).geojson()
    
    # flip coordinates from lon/lat to lat/lon
    coordinates = resp["features"][0]["geometry"]["coordinates"]
    flipped = [(lat, lon) for (lon, lat) in coordinates]
    
    return Route(
        distance=resp["features"][0]["properties"]["distance"],
        duration=resp["features"][0]["properties"]["duration"],
        polyline=folium.PolyLine(flipped),
    )

# %%
import itertools

frommapbox = {}
for from_station, to_station in itertools.combinations(stations, 2):
    
    # If the straight line distance is less than one and a half
    # miles, then get the cycling distance from the Mapbox API.
    straight_line = as_the_bird_flies(from_station, to_station)
    if straight_line < 1.5 * 1609:
        
        # Both directions because the route might be different
        # due to one-way streets, etc.
        frommapbox[(from_station, to_station)] = \
            get_route_from_mapbox(from_station, to_station)
        frommapbox[(to_station, from_station)] = \
            get_route_from_mapbox(to_station, from_station)

# %%
debugmap2 = basemap(stations)
frommapbox[(stations[4], stations[10])].polyline.add_to(debugmap2)
debugmap2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Step 5: Traveling Salesman, take 2

# %%
def cost_function_2(from_index, to_index):
    """Cost function for OR Tools"""
    from_station = stations[manager.IndexToNode(from_index)]
    to_station = stations[manager.IndexToNode(to_index)]
    
    try:
        route = frommapbox[(from_station, to_station)]
        return int(route.duration)  # in seconds
    
    except KeyError:
        # overestimate duration for routes we don't
        # have directions for (really want to avoid them)
        return as_the_bird_flies(from_station, to_station) * 5

# %%
manager_2 = pywrapcp.RoutingIndexManager(len(stations), 1, 0)
routing_2 = pywrapcp.RoutingModel(manager_2)
callback_ptr_2 = routing_2.RegisterTransitCallback(cost_function_2)
routing_2.SetArcCostEvaluatorOfAllVehicles(callback_ptr_2)
search_parameters_2 = pywrapcp.DefaultRoutingSearchParameters()
search_parameters_2.first_solution_strategy = (
    routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)
assignment_2 = routing_2.SolveWithParameters(search_parameters_2)

total_dist = assignment_2.ObjectiveValue()
print(f"Duration: {total_dist/3600:.3} hrs")
# Out:
# Duration: 6.62 hrs

# %%
route_2 = route_from_ortools_solution(assignment_2, routing_2, manager_2)
routemap_2 = basemap(stations)

for st1, st2 in route_2:
    try:
        polyline = frommapbox[(st1, st2)].polyline
        polyline.add_to(routemap_2)
    except KeyError:
        folium.PolyLine([st1.latlon, st2.latlon], color="pink").add_to(routemap_2)

routemap_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Modifying the cost function to penalize rides with durations under 2 minutes a little bit. This cost function considers 2 minutes (120 seconds) ride length the optimum. 90 second ride length gets the same cost as 150 seconds, 60 second ride length gets the same cost as 180 seconds.

# %%
def cost_function_3(from_index, to_index):
    """Cost function for OR Tools"""
    from_station = stations[manager.IndexToNode(from_index)]
    to_station = stations[manager.IndexToNode(to_index)]
    
    try:
        route = frommapbox[(from_station, to_station)]
        return int(abs(120 - route.duration))  # seconds
    
    except KeyError:
        # grossly overestimate duration for routes we don't
        # have directions for (really want to avoid them)
        return as_the_bird_flies(from_station, to_station) * 5

# %%
manager_3 = pywrapcp.RoutingIndexManager(len(stations), 1, 0)
routing_3 = pywrapcp.RoutingModel(manager_3)
callback_ptr_3 = routing_3.RegisterTransitCallback(cost_function_3)
routing_3.SetArcCostEvaluatorOfAllVehicles(callback_ptr_3)
search_parameters_3 = pywrapcp.DefaultRoutingSearchParameters()
search_parameters_3.first_solution_strategy = (
    routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)
assignment_3 = routing_3.SolveWithParameters(search_parameters_3)
# Out:
# <ortools.constraint_solver.pywrapcp.Assignment; proxy of <Swig Object of type 'operations_research::Assignment *' at 0x1103e51b0> >

# %%
route_3 = route_from_ortools_solution(assignment_3, routing_3, manager_3)
routemap_3 = basemap(stations)

for st1, st2 in route_3:
    polyline = frommapbox[(st1, st2)].polyline
    polyline.add_to(routemap_3)

routemap_3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
